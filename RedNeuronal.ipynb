# %% [markdown]
# <a href="https://colab.research.google.com/github/PapiChule/RedesNeuronales/blob/Red-Neuronal/RedNeuronal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as keras
from tensorflow.keras import layers
import pandas as pd
import numpy as np
from tensorflow.keras import datasets, layers, models
from tensorflow.keras.utils import to_categorical
from keras.models import Sequential
from keras.layers.core import Dense
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split

# %% [markdown]
# EJEMPLO 1

# %%
# Datos de entrenamiento
training_data = np.array([[0,0],[0,1],[1,0],[1,1]], "float32")

# Datos de salida
target_data = np.array([[0],[1],[1],[0]], "float32")

model = Sequential()
model.add(Dense(16, input_dim=2, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

model.compile(loss='mean_squared_error',
              optimizer='Adam',
              metrics=['binary_accuracy'])

model.fit(training_data, target_data, epochs=100, verbose=2)

print(model.predict(training_data).round())
# Out:
# Epoch 1/100
# 1/1 - 3s - loss: 0.2412 - binary_accuracy: 0.7500 - 3s/epoch - 3s/step
# Epoch 2/100
# 1/1 - 0s - loss: 0.2410 - binary_accuracy: 0.5000 - 18ms/epoch - 18ms/step
# Epoch 3/100
# 1/1 - 0s - loss: 0.2408 - binary_accuracy: 0.5000 - 25ms/epoch - 25ms/step
# Epoch 4/100
# 1/1 - 0s - loss: 0.2406 - binary_accuracy: 0.5000 - 21ms/epoch - 21ms/step
# Epoch 5/100
# 1/1 - 0s - loss: 0.2405 - binary_accuracy: 0.5000 - 12ms/epoch - 12ms/step
# Epoch 6/100
# 1/1 - 0s - loss: 0.2403 - binary_accuracy: 0.5000 - 15ms/epoch - 15ms/step
# Epoch 7/100
# 1/1 - 0s - loss: 0.2401 - binary_accuracy: 0.5000 - 55ms/epoch - 55ms/step
# Epoch 8/100
# 1/1 - 0s - loss: 0.2399 - binary_accuracy: 0.5000 - 36ms/epoch - 36ms/step
# Epoch 9/100
# 1/1 - 0s - loss: 0.2398 - binary_accuracy: 0.5000 - 16ms/epoch - 16ms/step
# Epoch 10/100
# 1/1 - 0s - loss: 0.2396 - binary_accuracy: 0.5000 - 47ms/epoch - 47ms/step
# Epoch 11/100
# 1/1 - 0s - loss: 0.2394 - binary_accuracy: 0.5000 - 17ms/epoch - 17ms/step
# ...

# %% [markdown]
# EJEMPLO 2

# %%
df = pd.read_csv('Iris.csv')
# print(df.head())

X = df.iloc[:,1:5].values
y = df.iloc[:,5].values

encoder =  LabelEncoder()
y1 = encoder.fit_transform(y)

Y = pd.get_dummies(y1).values

X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=0)

# %%
import tensorflow as tf

model = tf.keras.Sequential([
    tf.keras.layers.Dense(16, activation='relu'),
    tf.keras.layers.Dense(8, activation='tanh'),
    tf.keras.layers.Dense(3, activation='sigmoid')
  ])
model

model.compile(optimizer='rmsprop',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

model.fit(X_train, y_train, batch_size=50, epochs=100)
# Out:
# Epoch 1/100
# 3/3 [==============================] - 2s 8ms/step - loss: 1.7571 - accuracy: 0.3083
# Epoch 2/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1.6141 - accuracy: 0.3083
# Epoch 3/100
# 3/3 [==============================] - 0s 10ms/step - loss: 1.5223 - accuracy: 0.3083
# Epoch 4/100
# 3/3 [==============================] - 0s 14ms/step - loss: 1.4480 - accuracy: 0.3083
# Epoch 5/100
# 3/3 [==============================] - 0s 11ms/step - loss: 1.3847 - accuracy: 0.3083
# Epoch 6/100
# 3/3 [==============================] - 0s 11ms/step - loss: 1.3291 - accuracy: 0.3083
# Epoch 7/100
# 3/3 [==============================] - 0s 11ms/step - loss: 1.2765 - accuracy: 0.3083
# Epoch 8/100
# 3/3 [==============================] - 0s 6ms/step - loss: 1.2293 - accuracy: 0.3083
# Epoch 9/100
# 3/3 [==============================] - 0s 6ms/step - loss: 1.1915 - accuracy: 0.3083
# Epoch 10/100
# ...

# %%
loss, accuracy = model.evaluate(X_test, y_test, verbose=0)
print('Test loss:', loss)
print('Test accuracy:', accuracy)

y_pred = model.predict(X_test)
actual = np.argmax(y_test,axis=1)
predicted = np.argmax(y_pred,axis=1)

print(f"Actual: {actual}")
print(f"Predicted: {predicted}")
# Out:
# Test loss: 0.35944998264312744
# Test accuracy: 1.0
# 1/1 [==============================] - 0s 113ms/step
# Actual: [2 1 0 2 0 2 0 1 1 1 2 1 1 1 1 0 1 1 0 0 2 1 0 0 2 0 0 1 1 0]
# Predicted: [2 1 0 2 0 2 0 1 1 1 2 1 1 1 1 0 1 1 0 0 2 1 0 0 2 0 0 1 1 0]
